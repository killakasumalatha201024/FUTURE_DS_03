# %% [markdown]
# <a href="https://colab.research.google.com/github/killakasumalatha201024/FUTURE_DS_03/blob/main/Collage_Event_Feedback_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🎉🏫📝📊**COLLAGE EVENT FEEDBACK ANALYSIS**

# %%
from IPython.display import Image
url = "data:image/jpeg;base64,..."
display(Image(url=url, width=1000, height=200))
# Out:
# <img src="data:image/jpeg;base64,..." width="1000" height="200"/>

# %% [markdown]
# # **Importing Libraries📚**

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # **Data Collection🗃️**

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-2f7835dd-2963-40e9-ab4c-cb3d6337e342" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2f7835dd-2963-40e9-ab4c-cb3d6337e342">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Read the Excel file without specifying the engine
df = pd.read_csv("student_feedback.csv")
df
# Out:
#       Unnamed: 0  Student ID  Well versed with the subject  \
# 0              0         340                             5
# 1              1         253                             6
# 2              2         680                             7
# 3              3         806                             9
# 4              4         632                             8
# ...          ...         ...                           ...
# 996          996          55                             8
# 997          997         913                             5
# 998          998         199                             9
# 999          999         539                            10
# 1000        1000         759                             7
#
#       Explains concepts in an understandable way  Use of presentations  \
# 0                                              2                     7
# 1                                              5                     8
# ...

# %%
print(df.shape)
# Out:
# (1001, 10)

# %%
print(df.columns)
# Out:
# Index(['Unnamed: 0', 'Student ID', 'Well versed with the subject',
#        'Explains concepts in an understandable way', 'Use of presentations',
#        'Degree of difficulty of assignments', 'Solves doubts willingly',
#        'Structuring of the course',
#        'Provides support for students going above and beyond',
#        'Course recommendation based on relevance'],
#       dtype='object')

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1001 entries, 0 to 1000
# Data columns (total 10 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   Unnamed: 0                                            1001 non-null   int64
#  1   Student ID                                            1001 non-null   int64
#  2   Well versed with the subject                          1001 non-null   int64
#  3   Explains concepts in an understandable way            1001 non-null   int64
#  4   Use of presentations                                  1001 non-null   int64
#  5   Degree of difficulty of assignments                   1001 non-null   int64
#  6   Solves doubts willingly                               1001 non-null   int64
#  7   Structuring of the course                             1001 non-null   int64
# ...

# %%
print(df.describe())
# Out:
#         Unnamed: 0   Student ID  Well versed with the subject  \
# count  1001.000000  1001.000000                   1001.000000
# mean    500.000000   500.000000                      7.497502
# std     289.108111   289.108111                      1.692998
# min       0.000000     0.000000                      5.000000
# 25%     250.000000   250.000000                      6.000000
# 50%     500.000000   500.000000                      8.000000
# 75%     750.000000   750.000000                      9.000000
# max    1000.000000  1000.000000                     10.000000
#
#        Explains concepts in an understandable way  Use of presentations  \
# count                                 1001.000000           1001.000000
# mean                                     6.081918              5.942058
# std                                      2.597168              1.415853
# min                                      2.000000              4.000000
# ...

# %%
print(df.head())
# Out:
#    Unnamed: 0  Student ID  Well versed with the subject  \
# 0           0         340                             5
# 1           1         253                             6
# 2           2         680                             7
# 3           3         806                             9
# 4           4         632                             8
#
#    Explains concepts in an understandable way  Use of presentations  \
# 0                                           2                     7
# 1                                           5                     8
# 2                                           7                     6
# 3                                           6                     7
# 4                                          10                     8
#
#    Degree of difficulty of assignments  Solves doubts willingly  \
# 0                                    6                        9
# 1                                    6                        2
# ...

# %%
print(df.tail())
# Out:
#       Unnamed: 0  Student ID  Well versed with the subject  \
# 996          996          55                             8
# 997          997         913                             5
# 998          998         199                             9
# 999          999         539                            10
# 1000        1000         759                             7
#
#       Explains concepts in an understandable way  Use of presentations  \
# 996                                            7                     6
# 997                                            5                     6
# 998                                            5                     8
# 999                                            2                     7
# 1000                                           2                     4
#
#       Degree of difficulty of assignments  Solves doubts willingly  \
# 996                                     2                        5
# ...

# %%
print(df.isnull().sum())
# Out:
# Unnamed: 0                                              0
# Student ID                                              0
# Well versed with the subject                            0
# Explains concepts in an understandable way              0
# Use of presentations                                    0
# Degree of difficulty of assignments                     0
# Solves doubts willingly                                 0
# Structuring of the course                               0
# Provides support for students going above and beyond    0
# Course recommendation based on relevance                0
# dtype: int64

# %% [markdown]
# # **Data Cleaning🧹**

# %%
# Drop unnamed column if it exists
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]
df
# Out:
#       Student ID  Well versed with the subject  \
# 0            340                             5
# 1            253                             6
# 2            680                             7
# 3            806                             9
# 4            632                             8
# ...          ...                           ...
# 996           55                             8
# 997          913                             5
# 998          199                             9
# 999          539                            10
# 1000         759                             7
#
#       Explains concepts in an understandable way  Use of presentations  \
# 0                                              2                     7
# 1                                              5                     8
# 2                                              7                     6
# 3                                              6                     7
# ...

# %%
# Drop missing values
df.dropna(inplace=True)

# %%
print("\nCleaned Data:")
print(df.info())
# Out:
# Cleaned Data:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1001 entries, 0 to 1000
# Data columns (total 9 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   Student ID                                            1001 non-null   int64
#  1   Well versed with the subject                          1001 non-null   int64
#  2   Explains concepts in an understandable way            1001 non-null   int64
#  3   Use of presentations                                  1001 non-null   int64
#  4   Degree of difficulty of assignments                   1001 non-null   int64
#  5   Solves doubts willingly                               1001 non-null   int64
#  6   Structuring of the course                             1001 non-null   int64
#  7   Provides support for students going above and beyond  1001 non-null   int64
# ...

# %% [markdown]
# # **🔍 Exploratory Analysis (Ratings Distribution)**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Rating columns (from your dataset)
rating_cols = [
    "Well versed with the subject",
    "Explains concepts in an understandable way",
    "Use of presentations",
    "Degree of difficulty of assignments",
    "Solves doubts willingly",
    "Structuring of the course",
    "Provides support for students going above and beyond",
    "Course recommendation based on relevance"
]

# 1️⃣ Heatmap of Correlation between Rating Questions
plt.figure(figsize=(10,6))
sns.heatmap(df[rating_cols].corr(), annot=True, cmap="coolwarm", linewidths=0.5)
plt.title("Correlation between Feedback Questions")
plt.show()

# %%
# 2️⃣ Boxplots to check variation in ratings per question
plt.figure(figsize=(12,6))
sns.boxplot(data=df[rating_cols], palette="Set2")
plt.title("Boxplot of Ratings per Question")
plt.xticks(rotation=45)
plt.show()

# %%
# 3️⃣ Average Ratings per Question (Bar Chart)
avg_scores = df[rating_cols].mean().sort_values(ascending=False)
plt.figure(figsize=(8,5))
sns.barplot(x=avg_scores.values, y=avg_scores.index, palette="Blues_d")
plt.title("Average Ratings per Question")
plt.xlabel("Average Rating")
plt.show()
# Out:
# /tmp/ipython-input-3015240741.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=avg_scores.values, y=avg_scores.index, palette="Blues_d")

# %%
# 4️⃣ Distribution of Overall Average Score per Student
df["Overall Score"] = df[rating_cols].mean(axis=1)
plt.figure(figsize=(6,4))
sns.histplot(df["Overall Score"], kde=True, color="purple", bins=5)
plt.title("Distribution of Overall Student Feedback Score")
plt.xlabel("Average Rating per Student")
plt.show()

# %%
# 5️⃣ Radar/Spider Chart (visualizing multiple aspects together)
import numpy as np

categories = list(avg_scores.index)
values = avg_scores.values.flatten().tolist()
values += values[:1]  # repeat first value to close the circle

angles = np.linspace(0, 2*np.pi, len(categories), endpoint=False).tolist()
angles += angles[:1]

plt.figure(figsize=(8,8))
ax = plt.subplot(111, polar=True)
plt.xticks(angles[:-1], categories, color='grey', size=10)
ax.plot(angles, values, linewidth=2, linestyle='solid', color="blue")
ax.fill(angles, values, color="skyblue", alpha=0.4)
plt.title("Radar Chart of Average Ratings")
plt.show()

# %%
import numpy as np

# Count positive (>=4) and negative (<=2) per question
bias_data = {}
for col in rating_cols:
    positive = (df[col] >= 4).mean() * 100
    negative = (df[col] <= 2).mean() * 100
    bias_data[col] = positive - negative  # difference = bias

bias_series = pd.Series(bias_data).sort_values()

# Diverging bar chart
plt.figure(figsize=(8,6))
bias_series.plot(kind='barh', color=['red' if x < 0 else 'green' for x in bias_series])
plt.title("Positive vs Negative Rating Bias per Question")
plt.xlabel("Bias Score (% Positive - % Negative)")
plt.show()

# %%
from scipy.cluster.hierarchy import linkage, dendrogram
import seaborn as sns

# Hierarchical clustering on rating columns
plt.figure(figsize=(10, 6))
sns.clustermap(df[rating_cols].corr(), annot=True, cmap="coolwarm", linewidths=0.5)
plt.title("Clustering of Feedback Questions", pad=100)
plt.show()

# %% [markdown]
# # **Sentiment Analysis 😊😐😞**
#
# > Add blockquote

# %%
df
# Out:
#       Student ID  Well versed with the subject  \
# 0            340                             5
# 1            253                             6
# 2            680                             7
# 3            806                             9
# 4            632                             8
# ...          ...                           ...
# 996           55                             8
# 997          913                             5
# 998          199                             9
# 999          539                            10
# 1000         759                             7
#
#       Explains concepts in an understandable way  Use of presentations  \
# 0                                              2                     7
# 1                                              5                     8
# 2                                              7                     6
# 3                                              6                     7
# ...

# %%
import pandas as pd
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# Sample DataFrame
data = {
    'Feedback': [
        "The event was fantastic!",
        "I didn't like the organization.",
        "",
        None,
        "It was okay, nothing special."
    ]
}

df = pd.DataFrame(data)

# Initialize VADER analyzer
analyzer = SentimentIntensityAnalyzer()

# Function to get sentiment
def get_sentiment(text):
    if pd.isnull(text) or text.strip() == "":
        return "Neutral"
    score = analyzer.polarity_scores(text)['compound']
    if score > 0.05:
        return "Positive"
    elif score < -0.05:
        return "Negative"
    else:
        return "Neutral"

# Apply sentiment analysis
df['Sentiment'] = df['Feedback'].apply(get_sentiment)

# Display results
print("Sentiment distribution:")
print(df['Sentiment'].value_counts())

print("\nData with sentiment:")
print(df)
# Out:
# Sentiment distribution:
# Sentiment
# Negative    2
# Neutral     2
# Positive    1
# Name: count, dtype: int64
#
# Data with sentiment:
#                           Feedback Sentiment
# 0         The event was fantastic!  Positive
# 1  I didn't like the organization.  Negative
# 2                                    Neutral
# 3                             None   Neutral
# 4    It was okay, nothing special.  Negative

# %% [markdown]
# # **Advanced Visualization 📊**

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# Pie chart of sentiment share
plt.figure(figsize=(6,4))
df['Sentiment'].value_counts().plot(
    kind='pie',
    autopct='%1.1f%%',
    colors=["lightgreen", "salmon", "lightgrey"]
)
plt.title("Sentiment Share of Feedback")
plt.ylabel("")  # removes the y-label
plt.show()

# Word cloud from feedback (exclude empty/null)
text = " ".join(feedback for feedback in df['Feedback'].dropna() if feedback.strip() != "")
wordcloud = WordCloud(width=800, height=400, background_color="white").generate(text)

plt.figure(figsize=(10,5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.title("Most Common Feedback Words")
plt.show()

# %% [markdown]
# # **Insights & Recommendations 💡**

# %%
# Top 3 events by average rating
if 'Event' in df.columns and 'Rating' in df.columns:
    print("Top 3 Events by Average Rating:")
    top_events = df.groupby('Event')['Rating'].mean().sort_values(ascending=False).head(3)
    print(top_events)
else:
    print("Event or Rating column not found.")

# Sentiment distribution in %
print("\nSentiment Distribution (%):")
sentiment_dist = df['Sentiment'].value_counts(normalize=True) * 100
print(sentiment_dist.round(2))  # rounded for readability

# Show some negative feedback
print("\nSample Negative Feedback:")
negative_feedback = df[df['Sentiment'] == "Negative"]['Feedback']
if not negative_feedback.empty:
    print(negative_feedback.head())
else:
    print("No negative feedback found.")

# Recommendations (basic rule-based)
print("\nRecommendations:")
recommendations = [
    "Improve time management and scheduling",
    "Add more interactive/engaging activities",
    "Ensure clear communication in sessions"
]
for rec in recommendations:
    print("-", rec)
# Out:
# Event or Rating column not found.
#
# Sentiment Distribution (%):
# Sentiment
# Negative    40.0
# Neutral     40.0
# Positive    20.0
# Name: proportion, dtype: float64
#
# Sample Negative Feedback:
# 1    I didn't like the organization.
# 4      It was okay, nothing special.
# Name: Feedback, dtype: object
#
# Recommendations:
# - Improve time management and scheduling
# - Add more interactive/engaging activities
# - Ensure clear communication in sessions
